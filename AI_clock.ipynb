# %%
import datetime
city = input("enter city ")
current_time = datetime.datetime.now()
hour = current_time.hour
minute = current_time.minute
second = current_time.second
if city == "boston" :
    hour -= 4
elif city== "chicago":
    hour -= 5
elif city=="seattle":
    hour -=7
elif city=="amsterdam":
    hour+=2
elif city=="london":
    hour+=1
elif city=="paris":
    hour+=2
elif city=="tokyo":
    hour+=9
elif city=="berlin":
    hour+=2
elif city=="riyadh":
    hour+=3
elif city=="phuket":
    hour+=7
elif city=="buenos aires":
    hour-=3
elif city=="nigeria":
    hour+=1
elif city=="ontario":
    hour-=4
elif city=="british columbia":
    hour-=7
elif city=="new york":
    hour-=4
elif city=="mexico":
    hour-=5
elif city=="los angeles":
    hour-=7
elif city=="liverpool":
    hour+=1









elif city=="kolkata":
    hour+=0 
elif city=="chennai":
    hour+=0
elif city=="banglore":
    hour+=0
elif city=="hyderabad":
    hour+=0
elif city=="tirchy":
    hour+=0
elif city=="noida":
    hour+=0
elif city=="pune":
    hour+=0
elif city=="mumbai":
    hour+=0
elif city=="bhopal":
    hour+=0
elif city=="delhi":
    hour+=0
elif city=="cuddalore":
   hour+=0
elif city=="coimbatore":
    hour+=0
elif city=="ahmedabad":
    hour+=0
elif city=="jaipur":
    hour+=0
elif city=="surat":
    hour+=0
elif city=="indore":
    hour+=0
elif city=="chandigarg":
    hour+=0
elif city=="lucknow":
    hour+=0
elif city=="patna":
    hour+=0
elif city=="kochi":
    hour+=0
elif city=="nagpur":
    hour+=0
elif city=="kanpur":
    hour+=0
elif city=="shimla":
    hour+=0
elif city=="madurai":
    hour+=0
elif city=="amritsar":
    hour+=0
elif city=="nashik":
    hour+=0
elif city=="jodhpur":
    hour+=0
elif city=="udaipur":
    hour+=0
elif city=="raipur":
    hour+=0
elif city=="vijayawada":
    hour+=0
elif city=="meerut":
    hour+=0
elif city=="manglore":
    hour+=0
elif city=="faridabad":
    hour+=0
elif city=="Ranchi":
    hour+=0
elif city=="Mysuru":
    hour+=0



else:
     print("City not included")
     city="GMT"
print(city,str(hour) + ":" + str(minute) + ":" +str(second))
# Out:
# chennai 15:59:13
